# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style

# %%
df = pd.read_csv("data/train.csv")
df.head(50)
# Out:
#     id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0    1          1  20  50   0.000000   0.083334      0   5.837492
# 1    2          1  20  50   0.033652  18.383041      0   5.907794
# 2    3          1  20  50   0.067514  22.509278      0   7.876254
# 3    4          1  20  50   0.101542  22.808822      0  11.742872
# 4    5          1  20  50   0.135756  25.355850      0  12.234987
# 5    6          1  20  50   0.169698  27.259866      0  12.867706
# 6    7          1  20  50   0.203708  27.127486      0  14.695562
# 7    8          1  20  50   0.237723  26.807732      0  15.890699
# 8    9          1  20  50   0.271776  27.864715      0  15.539188
# 9   10          1  20  50   0.305732  28.313036      0  15.750094
# 10  11          1  20  50   0.339675  26.866758      0  17.296741
# 11  12          1  20  50   0.373680  26.762803      0  17.226439
# 12  13          1  20  50   0.407650  27.993274      0  16.171907
# 13  14          1  20  50   0.441804  26.789898      0  17.367044
# 14  15          1  20  50   0.476103  25.634070      0  18.070065
# 15  16          1  20  50   0.509996  26.280195      0  17.156137
# 16  17          1  20  50   0.544041  24.726714      0  18.280971
# 17  18          1  20  50   0.578179  23.467889      0  18.773086
# 18  19          1  20  50   0.612109  23.858434      0  17.859159
# 19  20          1  20  50   0.646055  21.883404      0  19.124597
# 20  21          1  20  50   0.680176  20.701046      0  19.335504
# 21  22          1  20  50   0.715327  20.843610      0  18.491878
# 22  23          1  20  50   0.749344  20.269191      0  18.562180
# 23  24          1  20  50   0.783241  19.693681      0  18.632482
# 24  25          1  20  50   0.817397  18.927285      0  18.843389
# 25  26          1  20  50   0.851411  18.093826      0  19.054295
# 26  27          1  20  50   0.885488  17.193955      0  19.265201
# 27  28          1  20  50   0.919468  16.419253      0  19.335504
# 28  29          1  20  50   0.953547  15.744684      0  19.335504
# 29  30          1  20  50   0.987487  14.931596      0  19.476108
# 30  31          1  20  50   1.021298   0.000000      1  19.546410
# 31  32          1  20  50   1.055426   0.000000      1  17.015533
# 32  33          1  20  50   1.089404   0.000000      1   9.563505
# 33  34          1  20  50   1.123387   0.000000      1   7.876254
# 34  35          1  20  50   1.157591   0.000000      1   8.649578
# 35  36          1  20  50   1.191510   0.000000      1   7.595045
# 36  37          1  20  50   1.225571   0.000000      1   7.665347
# 37  38          1  20  50   1.259531   0.000000      1   8.298067
# 38  39          1  20  50   1.293622   0.000000      1   7.243535
# 39  40          1  20  50   1.327631   0.000000      1   7.946556
# 40  41          1  20  50   1.361646   0.000000      1   7.595045
# 41  42          1  20  50   1.395615   0.000000      1   7.454441
# 42  43          1  20  50   1.429678   0.000000      1   8.157463
# 43  44          1  20  50   1.463903   0.000000      1   6.821722
# 44  45          1  20  50   1.497959   0.000000      1   7.173232
# 45  46          1  20  50   1.531981   0.779225      1   7.524743
# 46  47          1  20  50   1.565979   1.439041      1   6.962326
# 47  48          1  20  50   1.599878   1.994220      1   7.454441
# 48  49          1  20  50   1.634123   2.467240      1   7.595045
# 49  50          1  20  50   1.668141   2.863387      1   7.173232

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6036000 entries, 0 to 6035999
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   id         int64
#  1   breath_id  int64
#  2   R          int64
#  3   C          int64
#  4   time_step  float64
#  5   u_in       float64
#  6   u_out      int64
#  7   pressure   float64
# dtypes: float64(3), int64(5)
# memory usage: 368.4 MB

# %%
print(df.describe())
# Out:
#                  id     breath_id             R             C     time_step  \
# count  6.036000e+06  6.036000e+06  6.036000e+06  6.036000e+06  6.036000e+06
# mean   3.018000e+06  6.283886e+04  2.703618e+01  2.608072e+01  1.307225e+00
# std    1.742443e+06  3.633526e+04  1.959549e+01  1.715231e+01  7.659778e-01
# min    1.000000e+00  1.000000e+00  5.000000e+00  1.000000e+01  0.000000e+00
# 25%    1.509001e+06  3.137700e+04  5.000000e+00  1.000000e+01  6.428995e-01
# 50%    3.018000e+06  6.276550e+04  2.000000e+01  2.000000e+01  1.308123e+00
# 75%    4.527000e+06  9.430100e+04  5.000000e+01  5.000000e+01  1.965502e+00
# max    6.036000e+06  1.257490e+05  5.000000e+01  5.000000e+01  2.937238e+00
#
#                u_in         u_out      pressure
# count  6.036000e+06  6.036000e+06  6.036000e+06
# mean   7.321615e+00  6.204493e-01  1.122041e+01
# std    1.343470e+01  4.852752e-01  8.109703e+00
# min    0.000000e+00  0.000000e+00 -1.895744e+00
# 25%    3.936623e-01  0.000000e+00  6.329607e+00
# 50%    4.386146e+00  1.000000e+00  7.032628e+00
# 75%    4.983895e+00  1.000000e+00  1.364103e+01
# max    1.000000e+02  1.000000e+00  6.482099e+01

# %%
# Check for missing values in each column
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# id           0
# breath_id    0
# R            0
# C            0
# time_step    0
# u_in         0
# u_out        0
# pressure     0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['pressure'], kde=True)
plt.title("Distribution of Pressure")
plt.xlabel("Pressure (cmH2O)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,6), dpi= 80)
sns.heatmap(
    df.corr(), xticklabels=df.corr().columns,
    yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True, cbar=False
)
plt.title('Correlation between features', fontsize=16)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
